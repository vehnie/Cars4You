# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import KNNImputer
from rapidfuzz import process, fuzz
from category_encoders import TargetEncoder
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LassoCV
from sklearn.feature_selection import mutual_info_regression
from scipy import stats
import pickle

# %%
df_fixed = pd.read_csv('../data/df_fixed_typos.csv')
df_models = pd.read_csv('../data/car_models.csv')

# %%
# include only brand and models columns in df_fixed
df_fixed = df_fixed[['brand', 'model']]

# %%
# merge df_fixed and df_models
df = pd.concat([df_fixed, df_models], ignore_index=True).drop_duplicates(ignore_index=True)

# %%
# save df
df.to_csv('../data/all_car_models.csv', index=False)
